# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
history_df = pd.read_csv('./model_v1/iwpod_net_finetuned_history.csv', index_col='epoch')

# %%
#plot training loss
plt.figure(figsize=(10, 6))
plt.plot(history_df['loss'], label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
